# %%
#Get Estate Info "Year of Intake", "Estate Name" http://www.housingauthority.gov.hk/datagovhk/prh-estates.json
#Build a database from 2015 Flats with Suicide http://www.squarefoot.com.hk/chinese-hk/haunted/?date=2015

import requests
import numpy as np
from bs4 import BeautifulSoup

#1. Read json file of Public Rental Housing List
prh = (requests.get("http://www.housingauthority.gov.hk/datagovhk/prh-estates.json")).json()

#2. Scrape data of 2015 suicide events
#suicide_2015 = (requests.get("http://www.squarefoot.com.hk/chinese-hk/haunted/?date=2015")).text
#soup = BeautifulSoup(suicide_2015)

suicide_2015 = np.genfromtxt("http://www.squarefoot.com.hk/chinese-hk/haunted/?date=2015")
print (suicide_2015)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-0c5fc4b286cd> in <module>()
#      13 #soup = BeautifulSoup(suicide_2015)
#      14
# ---> 15 suicide_2015 = np.genfromtxt("http://www.squarefoot.com.hk/chinese-hk/haunted/?date=2015")
#      16 print (suicide_2015)
#
# /Users/leemungyim/anaconda3/lib/python3.5/site-packages/numpy/lib/npyio.py in genfromtxt(fname, dtype, comments, delimiter, skip_header, skip_footer, converters, missing_values, filling_values, usecols, names, excludelist, deletechars, replace_space, autostrip, case_sensitive, defaultfmt, unpack, usemask, loose, invalid_raise, max_rows)
#    1767             # Raise an exception ?
#    1768             if invalid_raise:
# -> 1769                 raise ValueError(errmsg)
#    1770             # Issue a warning ?
#    1771             else:
#
# ValueError: Some errors were detected !
# ...
